# %%
import networkx as nx

# %%
Gw = nx.DiGraph()
Gw.add_edge(1, 2, weight=31)
Gw.add_edge(2, 3, weight=31) 
Gw.add_edge(1, 4, weight=4)
Gw.add_edge(4, 5, weight=1)
Gw.add_edge(5, 3, weight=1)
Gw.add_edge(4, 6, weight=3)
Gw.add_edge(6, 7, weight=1)
Gw.add_edge(7, 3, weight=1)
Gw.add_edge(6, 8, weight=2)
Gw.add_edge(8, 9, weight=2)
Gw.add_edge(10, 11, weight=31)
Gw.add_edge(11, 12, weight=31)
Gw.add_edge(10, 13, weight=39)
Gw.add_edge(13, 15, weight=32)
Gw.add_edge(15, 9, weight=32)
Gw.add_edge(13, 14, weight=7)
Gw.add_edge(14, 16, weight=2)
Gw.add_edge(16, 9, weight=2)
Gw.add_edge(14, 17, weight=5)
Gw.add_edge(17, 3, weight=5)

# %%
G = nx.DiGraph()
G.add_edge(1, 2)
G.add_edge(2, 3 )
G.add_edge(1, 4)
G.add_edge(4, 5)
G.add_edge(5, 3)
G.add_edge(4, 6)
G.add_edge(6, 7)
G.add_edge(7, 3)
G.add_edge(6, 8)
G.add_edge(8, 9)
G.add_edge(10, 11)
G.add_edge(11, 12)
G.add_edge(10, 13)
G.add_edge(13, 15)
G.add_edge(15, 9)
G.add_edge(13, 14)
G.add_edge(14, 16)
G.add_edge(16, 9)
G.add_edge(14, 17)
G.add_edge(17, 3)
G.add_edge(12, 8)
G.add_edge(8, 10)

# %%
Ga = nx.Graph()
Ga.add_edge(1, 2)
Ga.add_edge(2, 3 )
Ga.add_edge(1, 4)
Ga.add_edge(4, 5)
Ga.add_edge(5, 3)
Ga.add_edge(4, 6)
Ga.add_edge(6, 7)
Ga.add_edge(7, 3)
Ga.add_edge(6, 8)
Ga.add_edge(8, 9)
Ga.add_edge(10, 11)
Ga.add_edge(11, 12)
Ga.add_edge(10, 13)
Ga.add_edge(13, 15)
Ga.add_edge(15, 9)
Ga.add_edge(13, 14) 
Ga.add_edge(14, 16)
Ga.add_edge(16, 9)
Ga.add_edge(14, 17)
Ga.add_edge(17, 3)

# %%
nx.has_path(Gw, 1, 13)
# Out:
# False

# %%
nx.is_simple_path(Gw, [1, 5])
# Out:
# False

# %%
from itertools import combinations

def find_split(fhg_model, threshold=2):
    
    # Creiamo il minimo di componenti connesse
    basic = nx.number_weakly_connected_components(fhg_model)

    output = []

    # Creiamo una lista delle combinazioni di threshold elementi dei nodi
    combinations_list = list(combinations(fhg_model.nodes(), threshold))



    # Rimuoviamo i nodi dal grafo e valutiamo se il numero di componenti connesse  aumenta
    
    # In caso positivo aggiungiamo ad output

    return output

# %%
for i in find_split(Gw, 4):
    for j in i:
        print(j)
# Out:
# 1
# 2
# 3
# 4
# 1
# 2
# 3
# 5
# 1
# 2
# 3
# 6
# 1
# 2
# 3
# 7
# 1
# 2
# 3
# 8
# 1
# 2
# 3
# 9
# 1
# 2
# 3
# 10
# 1
# 2
# 3
# 11
# 1
# 2
# 3
# 12
# 1
# 2
# 3
# 13
# 1
# 2
# 3
# 15
# 1
# 2
# 3
# 14
# 1
# 2
# 3
# 16
# 1
# 2
# 3
# 17
# 1
# 2
# 4
# 5
# 1
# 2
# 4
# 6
# 1
# 2
# 4
# 7
# 1
# 2
# 4
# 8
# 1
# 2
# 4
# 9
# 1
# 2
# 4
# 10
# 1
# 2
# 4
# 11
# 1
# 2
# 4
# 12
# 1
# 2
# 4
# 13
# 1
# 2
# 4
# 15
# 1
# 2
# 4
# 14
# 1
# 2
# 4
# 16
# 1
# 2
# 4
# 17
# 1
# 2
# 5
# 6
# 1
# 2
# 5
# 7
# 1
# 2
# 5
# 8
# 1
# 2
# 5
# 9
# 1
# 2
# 5
# 10
# 1
# 2
# 5
# 11
# 1
# 2
# 5
# 12
# 1
# 2
# 5
# 13
# 1
# 2
# 5
# 15
# 1
# 2
# 5
# 14
# 1
# 2
# 5
# 16
# 1
# 2
# 5
# 17
# 1
# 2
# 6
# 7
# 1
# 2
# 6
# 8
# 1
# 2
# 6
# 9
# 1
# 2
# 6
# 10
# 1
# 2
# 6
# 11
# 1
# 2
# 6
# 12
# 1
# 2
# 6
# 13
# 1
# 2
# 6
# 15
# 1
# 2
# 6
# 14
# 1
# 2
# 6
# 16
# 1
# 2
# 6
# 17
# 1
# 2
# 7
# 8
# 1
# 2
# 7
# 9
# 1
# 2
# 7
# 10
# 1
# 2
# 7
# 11
# 1
# 2
# 7
# 12
# 1
# 2
# 7
# 13
# 1
# 2
# 7
# 15
# 1
# 2
# 7
# 14
# 1
# 2
# 7
# 16
# 1
# 2
# 7
# 17
# ...
